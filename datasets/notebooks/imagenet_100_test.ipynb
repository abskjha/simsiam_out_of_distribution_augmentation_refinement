# %%
import sys
sys.path.append('..')
from imagenet100 import ImageNet100
# from augmentations import get_aug

# %%
transform= None

# %%
dataset = ImageNet100(subset_file='../imagenet100.txt', root='/scratch/leuven/346/vsc34686/datasets/Imagenet_downloads/',split='train', transform=transform)

# %%
it_data = iter(dataset)

# %%
next(it_data)[0][0].shape
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-26993a428e4e> in <module>
# ----> 1 next(it_data)[0][0].shape
#
# TypeError: 'Image' object does not support indexing

# %%
dataset.imgs[0]
# Out:
# ('/scratch/leuven/346/vsc34686/datasets/Imagenet_downloads/train/n02869837/n02869837_10001.jpg',
#  0)

# %%
len(dataset)
# Out:
# 126689

# %%
next(it_data)[0]
# Out:
# <PIL.Image.Image image mode=RGB size=374x500 at 0x7FEFF039EDD8>

# %%
import torch
sampler = torch.utils.data.distributed.Sampler(dataset)

# %%
dataloader = torch.utils.data.DataLoader(
        dataset, batch_size=10,
        num_workers=4, pin_memory=True, sampler=sampler, drop_last=True)

# %%
len(dataloader.dataset)
# Out:
# 126689
